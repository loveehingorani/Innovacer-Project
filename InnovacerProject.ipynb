# %%
import xlsxwriter
import random

# %%
import math

# %%
import pandas as pd

from pandas import DataFrame

# %%
pwd
# Out:
# 'C:\\Users\\Lovee Hingorani'

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is DC7A-04B0
#
#  Directory of C:\Users\Lovee Hingorani
#
# 04/19/2020  07:19 AM    <DIR>          .
# 04/19/2020  07:19 AM    <DIR>          ..
# 01/08/2020  06:22 PM    <DIR>          .android
# 05/09/2019  03:35 PM    <DIR>          .AndroidStudio3.4
# 10/15/2019  11:38 AM    <DIR>          .AndroidStudio3.5
# 01/25/2020  10:53 AM    <DIR>          .astropy
# 06/16/2019  07:08 PM               140 .bash_history
# 01/24/2020  10:41 PM    <DIR>          .conda
# 01/20/2019  04:12 PM    <DIR>          .config
# 03/09/2019  06:55 PM    <DIR>          .eclipse
# 05/11/2019  09:50 AM                16 .emulator_console_auth_token
# 06/17/2019  11:05 AM                95 .gitconfig
# 10/15/2019  12:12 PM    <DIR>          .gradle
# 04/18/2020  08:19 PM    <DIR>          .ipynb_checkpoints
# 01/24/2020  09:33 PM    <DIR>          .ipython
# 04/19/2020  07:17 AM    <DIR>          .jupyter
# 01/24/2020  09:39 PM    <DIR>          .matplotlib
# ...

# %%
variable= pd.read_csv('breastCancer.csv')
new_contents=[]
for line in variable:
    if not line.strip():
        continue 
    else: 
        new_contents.append(line)

# %%
variable
# Out:
#            ID Outcome   Time  radius_mean  texture_mean  perimeter_mean  \
# 0    119513.0       N   31.0        18.02         27.60          117.50
# 1      8423.0       N   61.0        17.99         10.38          122.80
# 2    842517.0       N  116.0        21.37         17.44          137.50
# 3    843483.0       N  123.0        11.42         20.38           77.58
# 4    843584.0       R   27.0        20.29         14.34          135.10
# ..        ...     ...    ...          ...           ...             ...
# 994       NaN     NaN    NaN          NaN           NaN             NaN
# 995       NaN     NaN    NaN          NaN           NaN             NaN
# 996       NaN     NaN    NaN          NaN           NaN             NaN
# 997       NaN     NaN    NaN          NaN           NaN             NaN
# 998       NaN     NaN    NaN          NaN           NaN             NaN
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  ...  \
# ...

# %%
new_contents
# Out:
# ['ID',
#  'Outcome',
#  'Time',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave_points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_std_dev',
#  'texture_std_dev',
#  'perimeter_std_dev',
#  'area_std_dev',
#  'smoothness_std_dev',
#  'compactness_std_dev',
#  'concavity_std_dev',
#  'concave_points_std_dev',
#  'symmetry_std_dev',
#  'fractal_dimension_std_dev',
#  'Worst_radius',
#  'Worst_texture',
#  'Worst_perimeter',
#  'Worst_area',
#  'Worst_smoothness',
#  'Worst_compactness',
#  'Worst_concavity',
#  'Worst_concave_points',
#  'Worst_symmetry',
#  'Worst_fractal_dimension',
#  'Tumor_Size',
#  'Lymph_Node_Status']

# %%
def loadCsv(filename):
    lines=pd.read_csv(r'breastCancer.csv')
    dataset=list(lines)
    for i in range(len(dataset)):
        dataset[i]=[auto[x] for x in dataset[i]]
    return dataset

# %%
data=variable.loc[0:197]

# %%
data.dtypes
# Out:
# ID                           float64
# Outcome                       object
# Time                         float64
# radius_mean                  float64
# texture_mean                 float64
# perimeter_mean               float64
# area_mean                    float64
# smoothness_mean              float64
# compactness_mean             float64
# concavity_mean               float64
# concave_points_mean          float64
# symmetry_mean                float64
# fractal_dimension_mean       float64
# radius_std_dev               float64
# texture_std_dev              float64
# perimeter_std_dev            float64
# area_std_dev                 float64
# smoothness_std_dev           float64
# compactness_std_dev          float64
# concavity_std_dev            float64
# concave_points_std_dev       float64
# symmetry_std_dev             float64
# fractal_dimension_std_dev    float64
# Worst_radius                 float64
# Worst_texture                float64
# ...

# %%
data
# Out:
#            ID Outcome   Time  radius_mean  texture_mean  perimeter_mean  \
# 0    119513.0       N   31.0        18.02         27.60          117.50
# 1      8423.0       N   61.0        17.99         10.38          122.80
# 2    842517.0       N  116.0        21.37         17.44          137.50
# 3    843483.0       N  123.0        11.42         20.38           77.58
# 4    843584.0       R   27.0        20.29         14.34          135.10
# ..        ...     ...    ...          ...           ...             ...
# 193  942640.0       N   10.0        22.52         21.92          146.90
# 194  943471.0       N    8.0        15.44         31.18          101.00
# 195   94547.0       N   12.0        17.17         29.19          110.00
# 196  947204.0       R    3.0        21.42         22.84          145.00
# 197  947489.0       N    6.0        16.70         28.13          110.30
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  ...  \
# ...

# %%
data.hist(column='area_mean')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B66EB73CC8>]],
#       dtype=object)

# %%
def splitDataset(dataset,splitRatio):
    trainSize=int(len(dataset)*splitRatio)
    trainSet=[]
    copy=list(dataset)
    while(len(trainSet)<trainSize):
        index=random.randrange(len(copy))
        trainSet.append(copy.pop(index))
    return [trainSet,copy]

# %%
def separatedByClass(dataset):
    separated=[]
    for i in range(len(dataset)):
        vector=dataset[i]
        if (vector[-1] not in separated):
            separated[vector[-1]]=[]
        separated[vector[-1]].append(vector)
    return separated

# %%
def mean(numbers):
    return sum(numbers)/float(len(numbers))

# %%
def stdev(numbers):
    avg=mean(numbers)
    variance=sum([pow(x-avg,2) for x in numbers])/float(len(numbers)-1)
    return math.sqrt(variance)

# %%
def summarize(dataset):
    summaries=[(mean(attribute),stdev(atttribute))for attribute in zip(*dataset)]
    del summaries[-1]
    return summaries

# %%
def summarizeByClass(dataset):
    separated= separatedByClass(dataset)
    summaries={}
    for classValue,instance in separated.items():
        summaries[classValue]=summarize(instances)
    return summaries

# %%
def calculateProbability(x,mean,stdev):
    exponent=math.exp(-(math.pow(x-mean,2)/(2*math.pow(stdev,2))))
    return (1/(math.sqrt(2*math.p1)*stdev))*exponent

# %%
def calculateClassProbabilities(summaries,inputVector):
    probabilities= {}
    for classValue,classSummaries in summaries.items():
        probabilities[classValue]=1
        for i in range(len(classSummaries)):
            mean,stdev=classSummaries[i]
            x=inputVector[i]
            probabilities[classValue]*=calculateProbability(x,mean,stdev)
        return probabilities

# %%
def predict(summaries,inputVector):
    probabilities= calculateClassProbabilities(summaries,inputVector)
    bestLabel,bestProb=None,-1
    for classValue ,probability in probabilites.items():
        if bestLabel is None or probability>bestProb:
            bestProb=probability
            bestValue=classValue
    return bestLabel

# %%
def getPredictions(summaries,testSet):
    prediction=[]
    for i in range(len(testSet)):
        result=predice(summaries,testSet[i])
        prediction.append(result)
    return prediction

# %%
def getAccuracy(testSet,prediction):
    correct=0
    for x in range(len(testSet)):
        if testSet[x][-1]==prediction[x]:
            correct+=1
    return (correct/float(len(testSet)))*100

# %%
def main():
    filename='breastCancer.csv'
    splitRatio =.67
    dataset=loadCsv(filename)
    trainingSet,testSet =splitDataset(dataset,splitRatio)
    summaries= summarizeByClass(trainingSet)
    predictions=getPredictions(summaries,testSet)
    accuracy =getAccuracy(testSet,predictions)
    print('Accuracy : {0}%'.format(accuracy))
main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-122-954bc04217ef> in <module>
#       8     accuracy =getAccuracy(testSet,predictions)
#       9     print('Accuracy : {0}%'.format(accuracy))
# ---> 10 main()
#      11
#
# <ipython-input-122-954bc04217ef> in main()
#       2     filename='breastCancer.csv'
#       3     splitRatio =.67
# ----> 4     dataset=loadCsv(filename)
#       5     trainingSet,testSet =splitDataset(dataset,splitRatio)
#       6     summaries= summarizeByClass(trainingSet)
#
# <ipython-input-121-42c5c27267cb> in loadCsv(filename)
#       3     dataset=list(lines)
#       4     for i in range(len(dataset)):
# ----> 5         dataset[i]=[auto[x] for x in dataset[i]]
#       6     return dataset
#
# <ipython-input-121-42c5c27267cb> in <listcomp>(.0)
#       3     dataset=list(lines)
#       4     for i in range(len(dataset)):
# ...

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-108-88811204d8e0> in main()
#       2     filename='breastCancer.csv'
#       3     splitRatio =.67
# ----> 4     dataset=loadCsv(filename)
#       5     trainingSet,testSet =splitDataset(data,splitRatio)
#       6     summaries= summarizeByClass(trainingSet)
#
# <ipython-input-107-e990e2640d33> in loadCsv(filename)
#       3     dataset=list(lines)
#       4     for i in range(len(dataset)):
# ----> 5         dataset[i]=[float(x) for x in dataset[i]]
#       6     return dataset
#
# <ipython-input-107-e990e2640d33> in <listcomp>(.0)
#       3     dataset=list(lines)
#       4     for i in range(len(dataset)):
# ----> 5         dataset[i]=[float(x) for x in dataset[i]]
#       6     return dataset
#
# ...

# %%
data
# Out:
#            ID Outcome   Time  radius_mean  texture_mean  perimeter_mean  \
# 0    119513.0       N   31.0        18.02         27.60          117.50
# 1      8423.0       N   61.0        17.99         10.38          122.80
# 2    842517.0       N  116.0        21.37         17.44          137.50
# 3    843483.0       N  123.0        11.42         20.38           77.58
# 4    843584.0       R   27.0        20.29         14.34          135.10
# ..        ...     ...    ...          ...           ...             ...
# 193  942640.0       N   10.0        22.52         21.92          146.90
# 194  943471.0       N    8.0        15.44         31.18          101.00
# 195   94547.0       N   12.0        17.17         29.19          110.00
# 196  947204.0       R    3.0        21.42         22.84          145.00
# 197  947489.0       N    6.0        16.70         28.13          110.30
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  ...  \
# ...
